# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 

# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("2017_raw.csv") 

# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#   projType   orderDate  orderYear orderMonth endUser userGroup matType  \
# 0   巴拿马子公司    2017/8/9       2017         八月  巴拿马PPC       HPH      国产
# 1   巴拿马子公司   2017/5/19       2017         五月  巴拿马PPC       HPH    HH国产
# 2   巴拿马子公司   2017/5/19       2017         五月  巴拿马PPC       HPH    HH国产
# 3   巴拿马子公司   2017/7/25       2017         七月  巴拿马PPC       HPH      国产
# 4   巴拿马子公司  2017/10/16       2017         十月  巴拿马PPC       HPH    HH国产
#
#                                     matDesc matName    amount
# 0  1000W投光灯 PF1K01S0A16X3GRP-C(208V/60HZ) G     投光灯  49958.11
# 1               ABB低压器件 HKF1-11  EZ-ABB[停用]    低压器件   2689.28
# 2          ABB低压器件 MS116 - 0.25  EZ-ABB[停用]    低压器件  53785.68
# 3  ABB低压器件 A12-30-10*110V 50Hz/110-120V 60H    低压器件    271.09
# 4  ABB低压器件 A12-30-10*110V 50Hz/110-120V 60H    低压器件    265.97

# %%
data["amount"]
# Out:
# 0      49958.11
# 1       2689.28
# 2      53785.68
# 3        271.09
# 4        265.97
# 5        331.50
# 6      27194.94
# 7       2758.24
# 8       2756.24
# 9      11606.17
# 10     11446.70
# 11     17200.76
# 12      7447.25
# 13      8486.40
# 14      6327.26
# 15      5141.70
# 16         0.00
# 17         0.00
# 18         0.00
# 19     11517.41
# 20         0.00
# 21         0.00
# 22         0.00
# 23         0.00
# 24      6170.04
# 25         0.00
# 26         0.00
# 27         0.00
# 28         0.00
# 29         0.00
#          ...
# 770     6063.63
# 771    12654.53
# 772     4745.45
# 773     6063.63
# 774     2896.15
# 775    31916.64
# 776    22198.51
# 777    11517.41
# 778    57195.60
# 779    54792.77
# 780     8863.54
# 781    17727.07
# 782    83781.18
# 783    55854.12
# 784     8863.54
# 785    22145.42
# 786     9929.66
# 787     4826.92
# 788     2417.33
# 789     4834.66
# 790      930.90
# 791     2417.33
# 792    14763.62
# 793     8777.08
# ...

# %%
import matplotlib.pyplot as plt


#创建频数分布直方图
plt.hist(data["amount"],bins=10)

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.boxplot(data["amount"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x117302be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x117311908>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x117302208>],
#  'medians': [<matplotlib.lines.Line2D at 0x117311cf8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11731c550>],
#  'means': []}
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import matplotlib
import  matplotlib.font_manager as fm

# sorted([f.name for f in fm.fontManager.ttflist])

#Matplotlib的字体管理
fm.FontProperties(fname="../crawl/msyh.ttf")  

print(matplotlib.matplotlib_fname())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
sorted([f.name for f in fm.fontManager.ttflist])
# Out:
# ['.Keyboard',
#  '.LastResort',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Display',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Rounded',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF Compact Text',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
#  '.SF NS Display Condensed',
# ...
